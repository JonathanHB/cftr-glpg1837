# %%
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
# Open and read the JSON file
with open('/home/jonathan/Documents/grabelab/cftr/ligand-simulations/nonlipidated/LJP-nodisp-water.json', 'r') as file:
    data = json.load(file)

# %%
type(data['object_logfile'])
# Out:
# str

# %%
json.loads(data['object_logfile'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 json.loads(data['object_logfile'])
#
# File ~/anaconda3/envs/serpents/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/envs/serpents/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
# ...

# %%
print(data['object_logfile'])
# Out:
# Beginning workflow at Wed Apr 23 20:06:56 2025
#
# Current Peregrine version: 621a3dea
#
#
#     ____  __________  ________________  _____   ________
#    / __ \/ ____/ __ \/ ____/ ____/ __ \/  _/ | / / ____/
#   / /_/ / __/ / /_/ / __/ / / __/ /_/ // //  |/ / __/
#  / ____/ /___/ _, _/ /___/ /_/ / _, _// // /|  / /___
# /_/   /_____/_/ |_/_____/\____/_/ |_/___/_/ |_/_____/
#
# peregrine: a unified package for different quantum chemistry engines
# copyright Corin & Ari Wagen, 2024
#
# Beginning calculation at Wed Apr 23 20:06:56 2025
#
# Input geometry information:
# +-------------------------------------------------------+
# | 44 atoms (24 heavy atoms)                             |
# | Charge 0, spin multiplicity 1                         |
# | Point group: C1                                       |
# | Rotational constants: 0.02 cm-1, 0.00 cm-1, 0.00 cm-1 |
# +-------------------------------------------------------+
#
# ...

# %%
data
# Out:
# {'uuid': '420445a5-06db-4486-bb73-743e243253cc',
#  'name': 'LJP',
#  'public': False,
#  'created_at': '2025-04-23T20:06:23.639753Z',
#  'updated_at': '2025-04-23T20:08:26.109797Z',
#  'started_at': '2025-04-23T20:06:49.323772Z',
#  'completed_at': '2025-04-23T20:08:26.063909Z',
#  'elapsed': 89.499351496,
#  'credits_charged': 1.53,
#  'email_when_complete': False,
#  'is_free': False,
#  'notes': '',
#  'object_data': {'mode': 'auto',
#   'engine': 'psi4',
#   'messages': [],
#   'settings': {'mode': 'rapid',
#    'tasks': ['charge'],
#    'method': 'b3lyp',
#    'basis_set': {'name': '6-31G(d)',
#     'overrides': [],
#     'cutoff_threshold': 1e-10},
#    'corrections': [],
#    'opt_settings': {'max_steps': 250,
#     'constraints': [],
#     'optimize_cell': False,
#     'energy_threshold': 5e-05,
#     'transition_state': False,
#     'max_gradient_threshold': 0.005,
#     'rms_gradient_threshold': 0.0035},
#    'scf_settings': {'do_diis': True,
#     'max_iters': 100,
# ...
